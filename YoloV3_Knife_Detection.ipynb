# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthickk-Rajah/Object-Detection-on-YoloV3/blob/master/YoloV3_Knife_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
# !unzip "/content/drive/My Drive/VVDN/darknet.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: darknet/data/labels/nec_knife_img564.txt
#   inflating: darknet/data/labels/nec_knife_img5640.txt
#   inflating: darknet/data/labels/nec_knife_img5641.txt
#   inflating: darknet/data/labels/nec_knife_img5642.txt
#   inflating: darknet/data/labels/nec_knife_img5643.txt
#   inflating: darknet/data/labels/nec_knife_img5644.txt
#   inflating: darknet/data/labels/nec_knife_img5645.txt
#   inflating: darknet/data/labels/nec_knife_img5646.txt
#   inflating: darknet/data/labels/nec_knife_img5647.txt
#   inflating: darknet/data/labels/nec_knife_img5648.txt
#   inflating: darknet/data/labels/nec_knife_img5649.txt
#   inflating: darknet/data/labels/nec_knife_img565.txt
#   inflating: darknet/data/labels/nec_knife_img5650.txt
#   inflating: darknet/data/labels/nec_knife_img5651.txt
#   inflating: darknet/data/labels/nec_knife_img5652.txt
#   inflating: darknet/data/labels/nec_knife_img5653.txt
# ...

# %%
# %cd /content/darknet 
# !make
# !chmod +x ./darknet
# Out:
# /content/darknet
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# gcc -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -DCUDNN  -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘time_gpu’:
# ./src/gemm.c:232:9: warning: ‘cudaThreadSynchronize’ is deprecated [-Wdeprecated-declarations]
#          cudaThreadSynchronize();
#          ^~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:11,
#                  from ./src/utils.h:5,
#                  from ./src/gemm.c:2:
# /usr/local/cuda/include/cuda_runtime_api.h:957:57: note: declared here
#  extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaThreadSynchronize(void);
#                                                          ^~~~~~~~~~~~~~~~~~~~~
# ...

# %%
# !rm /content/darknet/backup -r
# !ln -s /content/drive/'My Drive'/VVDN/backup /content/darknet

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,267 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dos2unix amd64 7.3.4-3 [351 kB]
# Fetched 351 kB in 2s (193 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %%
# !dos2unix ./data/train.txt
# !dos2unix ./data/val.txt
# !dos2unix ./data/yolo.data
# !dos2unix ./data/yolo.names
# !dos2unix ./cfg/yolov3_custom_train.cfg
# Out:
# dos2unix: converting file ./data/train.txt to Unix format...
# dos2unix: converting file ./data/val.txt to Unix format...
# dos2unix: converting file ./data/yolo.data to Unix format...
# dos2unix: converting file ./data/yolo.names to Unix format...
# dos2unix: converting file ./cfg/yolov3_custom_train.cfg to Unix format...

# %%
# %cd /content/darknet
# !./darknet detector train data/yolo.data cfg/yolov3_custom_train.cfg backup/yolov3_custom_train_5000.weights
# Out:
# Streaming output truncated to the last 5000 lines.
# Region 106 Avg IOU: 0.868953, Class: 0.000000, Obj: 0.871551, No Obj: 0.000036, .5R: 1.000000, .75R: 1.000000,  count: 1
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000001, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: 0.713983, Class: 0.000000, Obj: 0.639412, No Obj: 0.000088, .5R: 1.000000, .75R: 0.000000,  count: 1
# Region 106 Avg IOU: 0.853158, Class: 0.000000, Obj: 0.977689, No Obj: 0.000045, .5R: 1.000000, .75R: 1.000000,  count: 1
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: 0.692583, Class: 0.000000, Obj: 0.699376, No Obj: 0.000151, .5R: 1.000000, .75R: 0.000000,  count: 1
# Region 106 Avg IOU: 0.681642, Class: 0.000000, Obj: 0.663887, No Obj: 0.000030, .5R: 1.000000, .75R: 0.000000,  count: 1
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000215, .5R: -nan, .75R: -nan,  count: 0
# ...
